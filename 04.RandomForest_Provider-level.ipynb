# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Import Data

# %%
X_train = pd.read_csv('data_v1/train_all_feature.csv')

# %%
X_test= pd.read_csv('data_v1/test_all_feature.csv')

# %%
y_train = pd.read_csv('data_v1/y_train_new.csv')

# %%
y_test = pd.read_csv('data_v1/y_test_new.csv')

# %%
display(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (4328, 105)
# (1082, 105)
# (4328, 1)
# (1082, 1)

# %%
X_train.set_index('Provider',inplace = True)

# %%
X_train.head()
# Out:
#           DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# Provider
# PRV51001              213.600000                 1068.0
# PRV51004                2.080537                  100.0
# PRV51005                3.175966                  200.0
# PRV51008               53.860465                 1068.0
# PRV51011               23.586207                 1068.0
#
#           NoOfMonths_PartACov_mean  NoOfMonths_PartBCov_mean  \
# Provider
# PRV51001                 12.000000                 12.000000
# PRV51004                 11.865772                 11.959732
# PRV51005                 11.907296                 11.939914
# PRV51008                 12.000000                 12.000000
# PRV51011                 12.000000                 12.000000
#
#           OPAnnualReimbursementAmt_mean  OPAnnualReimbursementAmt_max  \
# Provider
# PRV51001                    2615.200000                         13460
# PRV51004                    2194.899329                         20900
# PRV51005                    2109.733906                         97510
# PRV51008                    2570.465116                         20500
# PRV51011                    1399.310345                          6340
#
#           OPAnnualReimbursementAmt_sum  OPAnnualDeductibleAmt_mean  \
# Provider
# PRV51001                         65380                  463.920000
# PRV51004                        327040                  622.751678
# PRV51005                       2457840                  636.328755
# PRV51008                        110530                  616.046512
# PRV51011                         81160                  366.724138
#
#           OPAnnualDeductibleAmt_max  OPAnnualDeductibleAmt_sum  ...  \
# Provider                                                        ...
# PRV51001                       2700                      11598  ...
# PRV51004                       7410                      92790  ...
# PRV51005                       6330                     741323  ...
# PRV51008                       4140                      26490  ...
# PRV51011                       1070                      21270  ...
#
#           totalProcCode_3722  totalProcCode_8151  totalProcCode_8872  \
# Provider
# PRV51001                   0                   0                   0
# PRV51004                   0                   0                   0
# PRV51005                   0                   0                   0
# PRV51008                   0                   0                   0
# PRV51011                   0                   0                   0
#
#           totalProcCode_9671  totalProcCode_4513  totalProcCode_5849  \
# Provider
# PRV51001                   0                   0                   0
# PRV51004                   0                   0                   0
# PRV51005                   0                   0                   0
# PRV51008                   0                   0                   0
# PRV51011                   0                   0                   0
#
#           totalProcCode_9390  totalProcCode_Other  TotalTeDiagCode  \
# Provider
# PRV51001                   0                  125         1.166158
# PRV51004                   0                  745         1.144495
# PRV51005                   0                 5825         1.174065
# PRV51008                   0                  215         1.144524
# PRV51011                   0                  290         1.141459
#
#           TotalTeProcCode
# Provider
# PRV51001         1.186518
# PRV51004         1.161067
# PRV51005         1.161067
# PRV51008         1.163394
# PRV51011         1.161067
#
# [5 rows x 104 columns]

# %%
X_test.set_index('Provider',inplace = True)

# %%
X_test.head()
# Out:
#           DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# Provider
# PRV51003              502.166667                 1068.0
# PRV51007               45.333333                 1068.0
# PRV51025              164.183908                 1068.0
# PRV51026                4.473684                  100.0
# PRV51041                7.941176                  100.0
#
#           NoOfMonths_PartACov_mean  NoOfMonths_PartBCov_mean  \
# Provider
# PRV51003                 11.818182                 11.871212
# PRV51007                 11.833333                 11.833333
# PRV51025                 12.000000                 12.000000
# PRV51026                 11.684211                 12.000000
# PRV51041                 12.000000                 12.000000
#
#           OPAnnualReimbursementAmt_mean  OPAnnualReimbursementAmt_max  \
# Provider
# PRV51003                    2678.181818                         31880
# PRV51007                    1729.722222                          6060
# PRV51025                    2288.965517                         23330
# PRV51026                    1811.578947                          6700
# PRV51041                    2287.647059                         28900
#
#           OPAnnualReimbursementAmt_sum  OPAnnualDeductibleAmt_mean  \
# Provider
# PRV51003                        353520                  737.121212
# PRV51007                        124540                  469.722222
# PRV51025                        199140                  621.379310
# PRV51026                        137680                  680.394737
# PRV51041                         77780                  613.823529
#
#           OPAnnualDeductibleAmt_max  OPAnnualDeductibleAmt_sum  ...  \
# Provider                                                        ...
# PRV51003                       9950                      97300  ...
# PRV51007                       1970                      33820  ...
# PRV51025                       8280                      54060  ...
# PRV51026                       2700                      51710  ...
# PRV51041                       7680                      20870  ...
#
#           totalProcCode_3722  totalProcCode_8151  totalProcCode_8872  \
# Provider
# PRV51003                   0                   0                   0
# PRV51007                   0                   0                   0
# PRV51025                   0                   0                   0
# PRV51026                   0                   0                   0
# PRV51041                   0                   0                   0
#
#           totalProcCode_9671  totalProcCode_4513  totalProcCode_5849  \
# Provider
# PRV51003                   0                   0                   0
# PRV51007                   0                   0                   0
# PRV51025                   0                   0                   0
# PRV51026                   0                   0                   0
# PRV51041                   0                   0                   0
#
#           totalProcCode_9390  totalProcCode_Other  TotalTeDiagCode  \
# Provider
# PRV51003                   0                  660         1.180504
# PRV51007                   0                  360         1.014301
# PRV51025                   0                  435         1.035489
# PRV51026                   0                  380         0.999096
# PRV51041                   0                  170         0.990358
#
#           TotalTeProcCode
# Provider
# PRV51003         1.100834
# PRV51007         1.022005
# PRV51025         1.052657
# PRV51026         1.022881
# PRV51041         1.022881
#
# [5 rows x 104 columns]

# %%
# There are two null values under DeductibleAmtPaid_mean and DeductibleAmtPaid_max for PRV54673
# Fillna with -99
X_test.DeductibleAmtPaid_mean.fillna(0, inplace = True)
X_test.DeductibleAmtPaid_max.fillna(0, inplace = True)

# %%
y_train = y_train.iloc[:,0].ravel()   #original y_train is a dataframe. Needs to convert to 1d array for modeling

# %%
y_test = y_test.iloc[:,0].ravel()

# %%
features = list(X_train.columns)
features2= features[:-2]

# %%
X_train2 = X_train[features2]
X_test2 = X_test[features2]

# %%
display(X_train2.shape, X_test2.shape)
# Out:
# (4328, 102)
# (1082, 102)

# %% [markdown]
# ## 2. Random Forest, balanced class weight, all features

# %%
#param_grid = {
#              'max_depth': [15,20,25,30,50],
#            'n_estimators':[150,300,500],
#            'min_samples_split':[2,4,6,8]}
#rfc2 = RandomForestClassifier(class_weight = 'balanced', random_state = 42)
#rfc2_gsv = GridSearchCV(rfc2, param_grid = param_grid,scoring = 'average_precision',cv=5)
#rfc2_gsv.fit(X_train2, y_train)
#rfc2_gsv.best_params_
# Out:
# {'max_depth': 30, 'min_samples_split': 4, 'n_estimators': 500}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

rfc2 = RandomForestClassifier(max_depth = 30, min_samples_split= 4, n_estimators = 500, class_weight = 'balanced', random_state = 42)

# %%
train_scores2 = cross_val_score(rfc2, X_train2, y_train, scoring = 'average_precision', cv=5)
train_scores2.mean()
# Out:
# 0.7044420980659687

# %%
rfc2.fit(X_train2, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=30,
#                        min_samples_split=4, n_estimators=500, random_state=42)

# %%
y_train_pred2 = rfc2.predict(X_train2)
y_train_pred_proba2 = rfc2.predict_proba(X_train2)

# %%
y_test_pred2 = rfc2.predict(X_test2)
y_test_pred_proba2 = rfc2.predict_proba(X_test2)

# %%
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_estimator(rfc2, X_train2, y_train)
plt.title("Train ROC Curve, all features")
RocCurveDisplay.from_estimator(rfc2, X_test2, y_test)
plt.title("Test ROC Curve, all features")
# Out:
# Text(0.5, 1.0, 'Test ROC Curve, all features')

# %%
#plot train PR Curve 
from sklearn.metrics import precision_recall_curve
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_recall_curve.html
from sklearn.metrics import auc,plot_precision_recall_curve
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.auc.html

train_precision2, train_recall2, train_thresholds2 = precision_recall_curve(y_train, y_train_pred_proba2[:, 1])
train_auc_precision_recall2 = auc(train_recall2, train_precision2)
print('Train PR-AUC is {:.2f}'.format(train_auc_precision_recall2))

print('min threshold:{:.2f}'.format(min(train_thresholds2)), 'max threshold:{:.2f}'.format(max(train_thresholds2)))

plt.plot(train_recall2, train_precision2)
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Train Precision-Recall Curve, all features,PRAUC=1.0')
# Out:
# Train PR-AUC is 1.00
# min threshold:0.57 max threshold:1.00
# Text(0.5, 1.0, 'Train Precision-Recall Curve, all features,PRAUC=1.0')

# %%
from sklearn.metrics import auc,plot_precision_recall_curve
from sklearn.metrics import precision_recall_curve

test_precision2, test_recall2, test_thresholds2 = precision_recall_curve(y_test, y_test_pred_proba2[:, 1])
test_auc_precision_recall2 = auc(test_recall2, test_precision2)
print('Test PR-AUC is {:.2f}'.format(test_auc_precision_recall2))

print('min threshold:{:.2f}'.format(min(test_thresholds2)), 'max threshold:{:.2f}'.format(max(test_thresholds2)))

plt.plot(test_recall2, test_precision2)
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Test Precision-Recall Curve, all features,PRAUC=0.70')
plt.show()
# Out:
# Test PR-AUC is 0.70
# min threshold:0.00 max threshold:0.99

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

thresholds = np.arange(0,1,0.05,dtype = float)
prec_scores2 = []
recall_scores2 = []

for i in range(len(thresholds)):
    y_test_pred_new = (rfc2.predict_proba(X_test2)[:,1]>thresholds[i]).astype(int)
    prec_scores2.append(precision_score(y_test, y_test_pred_new))
    recall_scores2.append(recall_score(y_test, y_test_pred_new))

plt.plot(thresholds, prec_scores2, marker = 'o',label = 'precision scores')
plt.plot(thresholds, recall_scores2,marker = 'o',label = 'recall scores')
plt.legend()
plt.title('Test Precision and Recall Scores vs.Thresholds, all Features')
plt.show()

# %%
importances = rfc2.feature_importances_
features = rfc2.feature_names_in_
logreg_importances = pd.Series(importances, index = features)
logreg_importances.sort_values(ascending = False)
# Out:
# MaxHospitalDays                  0.092852
# TotalInscClaimAmtReimbursed      0.075754
# totalDiagCode_41401              0.045087
# TotalIPAnnualReimbursementAmt    0.044740
# MaxInscClaimAmtReimbursed        0.041462
#                                    ...
# totalProcCode_9671               0.000000
# totalProcCode_4513               0.000000
# totalProcCode_5849               0.000000
# totalProcCode_9390               0.000000
# totalProcCode_8154               0.000000
# Length: 102, dtype: float64

# %%
top50features = logreg_importances.sort_values(ascending = False)[:50].index

# %%
logreg_importances.loc[top50features]
# Out:
# MaxHospitalDays                           0.092852
# TotalInscClaimAmtReimbursed               0.075754
# totalDiagCode_41401                       0.045087
# TotalIPAnnualReimbursementAmt             0.044740
# MaxInscClaimAmtReimbursed                 0.041462
# TotalProcCodeNum                          0.035793
# TotalIPAnnualDeductibleAmtdf              0.026262
# totalDiagCode_4280                        0.024395
# TotalMediumHighFreqProcCodeNumPerClaim    0.023289
# MaxDiagCodeNumPerClaim                    0.022999
# TotalDiagCodeNum                          0.022486
# MaxProcCodeNumPerClaim                    0.019907
# MeanProcCodeNumPerClaim                   0.019444
# TotalMediumFreqProcCodeNumPerClaim        0.018484
# totalDiagCode_42731                       0.018369
# TotalHighFreqProcCodeNumPerClaim          0.018101
# totalDiagCode_496                         0.017774
# totalDiagCode_25000                       0.013480
# DeductibleAmtPaid_max                     0.012975
# totalDiagCode_53081                       0.011561
# ClmsperBene                               0.011519
# OPAnnualReimbursementAmt_sum              0.010907
# totalDiagCode_2449                        0.010582
# totalDiagCode_Other                       0.010155
# MeanHospitalDays                          0.010065
# totalDiagCode_4019                        0.010016
# MeanInscClaimAmtReimbursed                0.009954
# OPAnnualDeductibleAmt_sum                 0.009380
# DeductibleAmtPaid_mean                    0.009175
# MaxIPAnnualReimbursementAmt               0.009101
# ClaimCounts                               0.009058
# uniqBeneCount                             0.008937
# ClaimPeriod                               0.008326
# totalProcCode_Other                       0.007891
# totalDiagCode_2724                        0.007634
# totalDiagCode_2589                        0.007385
# InClmsPct                                 0.007204
# MeanMediumFreqDiagCodeNumPerClaim         0.007066
# MeanDiagCodeNumPerClaim                   0.007014
# MeanIPAnnualDeductibleAmt                 0.006783
# Chronic_Heartfailure_Frac                 0.006728
# MeanIPAnnualReimbursementAmt              0.006394
# Chronic_rheumatoidarthritis_Frac          0.006392
# MeanRareFreqDiagCodeNumPerClaim           0.006337
# RenalDiseaseIndicator                     0.006025
# Gender                                    0.005815
# ClmsperOPPhysn                            0.005765
# Chronic_Depression_Frac                   0.005729
# Chronic_ObstrPulmonary_Frac               0.005598
# OPAnnualDeductibleAmt_max                 0.005570
# dtype: float64

# %%
fig = plt.figure(figsize = (6,10))
logreg_importances.loc[top50features].sort_values(ascending = True).plot.barh(title = 'Top 50 Features of Importance')
plt.xlabel('coefficient')
# Out:
# Text(0.5, 0, 'coefficient')

# %%
# use CalibrateClassifierCV to calibrate probability
from sklearn.calibration import CalibratedClassifierCV
calibrated_clf = CalibratedClassifierCV(base_estimator=rfc2,cv='prefit',method = 'isotonic')
calibrated_clf.fit(X_test2, y_test)
# Out:
# CalibratedClassifierCV(base_estimator=RandomForestClassifier(class_weight='balanced',
#                                                              max_depth=30,
#                                                              min_samples_split=4,
#                                                              n_estimators=500,
#                                                              random_state=42),
#                        cv='prefit', method='isotonic')

# %%
y_test_proba_isotonic = calibrated_clf.predict_proba(X_test2)

# %%
thresholds = np.arange(0,1,0.05,dtype = float)
prec_scores2_isotonic = []
recall_scores2_isotonic = []

for i in range(len(thresholds)):
    y_test_pred_new = (calibrated_clf.predict_proba(X_test2)[:,1]>thresholds[i]).astype(int)
    prec_scores2_isotonic.append(precision_score(y_test, y_test_pred_new))
    recall_scores2_isotonic.append(recall_score(y_test, y_test_pred_new))

plt.plot(thresholds, prec_scores2_isotonic, marker = 'o',label = 'precision scores')
plt.plot(thresholds, recall_scores2_isotonic,marker = 'o',label = 'recall scores')
plt.legend()
plt.title('Calibrated Test Precision and Recall Scores, all Features')
plt.xlabel('Threshold Values')
plt.show()

# %% [markdown]
# ### 3. RandomForest, balanced class weight, top 50 features

# %%
X_train_top50_2 = X_train[top50features]
X_test_top50_2 = X_test[top50features]

display(X_train_top50_2.shape, X_test_top50_2.shape)
# Out:
# (4328, 50)
# (1082, 50)

# %%
#param_grid = {
              'max_depth': [15,20,25,30,50],
            'n_estimators':[150,300,500,700],
            'min_samples_split':[2,4,6,8]}
#rfc3 = RandomForestClassifier(class_weight = 'balanced', random_state = 42)
#rfc3_gsv = GridSearchCV(rfc3, param_grid = param_grid,scoring = 'average_precision',cv=5)
#rfc3_gsv.fit(X_train_top50_2, y_train)
#rfc3_gsv.best_params_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [53], in <cell line: 7>()
#       5 rfc3 = RandomForestClassifier(class_weight = 'balanced', random_state = 42)
#       6 rfc3_gsv = GridSearchCV(rfc3, param_grid = param_grid,scoring = 'average_precision',cv=5)
# ----> 7 rfc3_gsv.fit(X_train_top50_2, y_train)
#       8 rfc3_gsv.best_params_
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    1390 def _run_search(self, evaluate_candidates):
#    1391     """Search all candidates in param_grid"""
# -> 1392     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:450, in BaseForest.fit(self, X, y, sample_weight)
#     439 trees = [
#     440     self._make_estimator(append=False, random_state=random_state)
#     441     for i in range(n_more_estimators)
#     442 ]
#     444 # Parallel loop: we prefer the threading backend as the Cython code
#     445 # for fitting the trees is internally releasing the Python GIL
#     446 # making threading more efficient than multiprocessing in
#     447 # that case. However, for joblib 0.12+ we respect any
#     448 # parallel_backend contexts set at a higher level,
#     449 # since correctness does not rely on using threads.
# --> 450 trees = Parallel(
#     451     n_jobs=self.n_jobs,
#     452     verbose=self.verbose,
#     453     **_joblib_parallel_args(prefer="threads"),
#     454 )(
#     455     delayed(_parallel_build_trees)(
#     456         t,
#     457         self,
#     458         X,
#     459         y,
#     460         sample_weight,
#     461         i,
#     462         len(trees),
#     463         verbose=self.verbose,
#     464         class_weight=self.class_weight,
#     465         n_samples_bootstrap=n_samples_bootstrap,
#     466     )
#     467     for i, t in enumerate(trees)
#     468 )
#     470 # Collect newly grown trees
#     471 self.estimators_.extend(trees)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:185, in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     182     elif class_weight == "balanced_subsample":
#     183         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 185     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186 else:
#     187     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:420, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     409 else:
#     410     builder = BestFirstTreeBuilder(
#     411         splitter,
#     412         min_samples_split,
#    (...)
#     417         self.min_impurity_decrease,
#     418     )
# --> 420 builder.build(self.tree_, X, y, sample_weight)
#     422 if self.n_outputs_ == 1 and is_classifier(self):
#     423     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
rfc3 = RandomForestClassifier(max_depth = 50, min_samples_split = 6, n_estimators =500, class_weight = 'balanced', random_state = 42)
train_scores3 = cross_val_score(rfc3, X_train_top50_2, y_train, scoring= 'average_precision', cv=5)

# %%
train_scores3.mean()
# Out:
# 0.7284704143095119

# %%
rfc3.fit(X_train_top50_2, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=50,
#                        min_samples_split=6, n_estimators=500, random_state=42)

# %%
y_train_pred3 = rfc3.predict(X_train_top50_2)
y_train_pred_proba3 = rfc3.predict_proba(X_train_top50_2)

y_test_pred3 = rfc3.predict(X_test_top50_2)
y_test_pred_proba3 = rfc3.predict_proba(X_test_top50_2)

# %%
RocCurveDisplay.from_estimator(rfc3, X_train_top50_2, y_train)
plt.title("Train ROC Curve, top 50 features")
RocCurveDisplay.from_estimator(rfc3, X_test_top50_2, y_test)
plt.title("Test ROC Curve, top 50 features")
# Out:
# Text(0.5, 1.0, 'Test ROC Curve, top 50 features')

# %%
#plot train PR Curve 
train_precision3, train_recall3, train_thresholds3 = precision_recall_curve(y_train, y_train_pred_proba3[:, 1])
train_auc_precision_recall3 = auc(train_recall3, train_precision3)
print('Train PR-AUC is {:.2f}'.format(train_auc_precision_recall3))

print('min threshold:{:.2f}'.format(min(train_thresholds3)), 'max threshold:{:.2f}'.format(max(train_thresholds3)))

plt.plot(train_recall3, train_precision3)
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Train Precision-Recall Curve, top 50 features,PRAUC=1.0')
# Out:
# Train PR-AUC is 1.00
# min threshold:0.53 max threshold:1.00
# Text(0.5, 1.0, 'Train Precision-Recall Curve, top 50 features,PRAUC=1.0')

# %%
test_precision3, test_recall3, test_thresholds3 = precision_recall_curve(y_test, y_test_pred_proba3[:, 1])
test_auc_precision_recall3 = auc(test_recall3, test_precision3)
print('Test PR-AUC is {:.2f}'.format(test_auc_precision_recall3))

print('min threshold:{:.2f}'.format(min(test_thresholds3)), 'max threshold:{:.2f}'.format(max(test_thresholds3)))

plt.plot(test_recall3, test_precision3)
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Test Precision-Recall Curve, top 50 features,PRAUC=0.71')
plt.show()
# Out:
# Test PR-AUC is 0.71
# min threshold:0.00 max threshold:1.00

# %%
# calibrate probability

calibrated_clf3 = CalibratedClassifierCV(base_estimator=rfc3,cv='prefit',method = 'isotonic')
calibrated_clf3.fit(X_test_top50_2, y_test)
# Out:
# CalibratedClassifierCV(base_estimator=RandomForestClassifier(class_weight='balanced',
#                                                              max_depth=50,
#                                                              min_samples_split=6,
#                                                              n_estimators=500,
#                                                              random_state=42),
#                        cv='prefit', method='isotonic')

# %%
y_test_proba_isotonic3 = calibrated_clf3.predict_proba(X_test_top50_2)

# %%
thresholds = np.arange(0,1,0.05,dtype = float)
prec_scores3_isotonic = []
recall_scores3_isotonic = []

for i in range(len(thresholds)):
    y_test_pred_new = (calibrated_clf3.predict_proba(X_test_top50_2)[:,1]>thresholds[i]).astype(int)
    prec_scores3_isotonic.append(precision_score(y_test, y_test_pred_new))
    recall_scores3_isotonic.append(recall_score(y_test, y_test_pred_new))

plt.plot(thresholds, prec_scores3_isotonic, marker = 'o',label = 'precision scores')
plt.plot(thresholds, recall_scores3_isotonic,marker = 'o',label = 'recall scores')
plt.legend()
plt.title('Test Precision and Recall Scores vs.Thresholds, Top 50 Features')
plt.show()

# %% [markdown]
# ### 4. RandomForest, balanced class weight, top 25 features

# %%
top25features = logreg_importances.sort_values(ascending = False)[:25].index

X_train_top25_2 = X_train[top25features]
X_test_top25_2 = X_test[top25features]

display(X_train_top25_2.shape, X_test_top25_2.shape)
# Out:
# (4328, 25)
# (1082, 25)

# %%
#param_grid = {
#              'max_depth': [15,20,25,30,50],
#            'n_estimators':[150,300,500,700],
#            'min_samples_split':[2,4,6,8]}
#rfc4 = RandomForestClassifier(class_weight = 'balanced', random_state = 42)
#rfc4_gsv = GridSearchCV(rfc4, param_grid = param_grid,scoring = 'average_precision',cv=5)
#rfc4_gsv.fit(X_train_top25_2, y_train)
#rfc4_gsv.best_params_
# Out:
# {'max_depth': 25, 'min_samples_split': 4, 'n_estimators': 700}

# %%
rfc4 = RandomForestClassifier(max_depth = 25, min_samples_split = 4, n_estimators =700, class_weight = 'balanced', random_state = 42)
train_scores4 = cross_val_score(rfc4, X_train_top25_2, y_train, scoring= 'average_precision', cv=5)

# %%
train_scores4.mean()
# Out:
# 0.7329579845878852

# %%
rfc4.fit(X_train_top25_2, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=25,
#                        min_samples_split=4, n_estimators=700, random_state=42)

# %%
y_train_pred4 = rfc4.predict(X_train_top25_2)
y_train_pred_proba4 = rfc4.predict_proba(X_train_top25_2)

y_test_pred4 = rfc4.predict(X_test_top25_2)
y_test_pred_proba4 = rfc4.predict_proba(X_test_top25_2)

# %%
RocCurveDisplay.from_estimator(rfc4, X_train_top25_2, y_train)
plt.title("Train ROC Curve, top 25 features")
RocCurveDisplay.from_estimator(rfc4, X_test_top25_2, y_test)
plt.title("Test ROC Curve, top 25 features")
# Out:
# Text(0.5, 1.0, 'Test ROC Curve, top 25 features')

# %%
#plot train PR Curve 
train_precision4, train_recall4, train_thresholds4 = precision_recall_curve(y_train, y_train_pred_proba4[:, 1])
train_auc_precision_recall4 = auc(train_recall4, train_precision4)
print('Train PR-AUC is {:.2f}'.format(train_auc_precision_recall4))

print('min threshold:{:.2f}'.format(min(train_thresholds4)), 'max threshold:{:.2f}'.format(max(train_thresholds4)))

plt.plot(train_recall4, train_precision4)
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Train Precision-Recall Curve, top 25 features,PRAUC=1.0')
# Out:
# Train PR-AUC is 1.00
# min threshold:0.57 max threshold:1.00
# Text(0.5, 1.0, 'Train Precision-Recall Curve, top 25 features,PRAUC=1.0')

# %%
test_precision4, test_recall4, test_thresholds4 = precision_recall_curve(y_test, y_test_pred_proba4[:, 1])
test_auc_precision_recall4 = auc(test_recall4, test_precision4)
print('Test PR-AUC is {:.2f}'.format(test_auc_precision_recall4))

print('min threshold:{:.2f}'.format(min(test_thresholds4)), 'max threshold:{:.2f}'.format(max(test_thresholds4)))

plt.plot(test_recall4, test_precision4)
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Test Precision-Recall Curve, top 25 features,PRAUC=0.72')
plt.show()
# Out:
# Test PR-AUC is 0.72
# min threshold:0.00 max threshold:0.99

# %%
# calibrate probability

calibrated_clf4 = CalibratedClassifierCV(base_estimator=rfc4,cv='prefit',method = 'isotonic')
calibrated_clf4.fit(X_test_top25_2, y_test)
# Out:
# CalibratedClassifierCV(base_estimator=RandomForestClassifier(class_weight='balanced',
#                                                              max_depth=25,
#                                                              min_samples_split=4,
#                                                              n_estimators=700,
#                                                              random_state=42),
#                        cv='prefit', method='isotonic')

# %%
y_test_proba_isotonic4 = calibrated_clf4.predict_proba(X_test_top25_2)

# %%
thresholds = np.arange(0,1,0.05,dtype = float)
prec_scores4_isotonic = []
recall_scores4_isotonic = []

for i in range(len(thresholds)):
    y_test_pred_new = (calibrated_clf4.predict_proba(X_test_top25_2)[:,1]>thresholds[i]).astype(int)
    prec_scores4_isotonic.append(precision_score(y_test, y_test_pred_new))
    recall_scores4_isotonic.append(recall_score(y_test, y_test_pred_new))

plt.plot(thresholds, prec_scores4_isotonic, marker = 'o',label = 'precision scores')
plt.plot(thresholds, recall_scores4_isotonic,marker = 'o',label = 'recall scores')
plt.legend()
plt.title('Calibrated Test Precision and Recall Scores vs.Thresholds, Top 25 Features')
plt.xlabel('Threshold Values')
plt.show()

# %% [markdown]
# ### 5. RandomForest, balanced class weight, top 10  features

# %%
top10features = logreg_importances.sort_values(ascending = False)[:10].index

X_train_top10_2 = X_train[top10features]
X_test_top10_2 = X_test[top10features]

display(X_train_top10_2.shape, X_test_top10_2.shape)
# Out:
# (4328, 10)
# (1082, 10)

# %%
#param_grid = {
#              'max_depth': [15,20,25,30,50],
#            'n_estimators':[150,300,500,700],
#            'min_samples_split':[2,4,6,8]}
#rfc5 = RandomForestClassifier(class_weight = 'balanced', random_state = 42)
#rfc5_gsv = GridSearchCV(rfc5, param_grid = param_grid,scoring = 'average_precision',cv=5)
#rfc5_gsv.fit(X_train_top10_2, y_train)
#rfc5_gsv.best_params_
# Out:
# {'max_depth': 25, 'min_samples_split': 4, 'n_estimators': 300}

# %%
rfc5 = RandomForestClassifier(max_depth = 25, min_samples_split = 4, n_estimators =300, class_weight = 'balanced', random_state = 42)
train_scores5 = cross_val_score(rfc5, X_train_top10_2, y_train, scoring= 'average_precision', cv=5)

# %%
train_scores5.mean()
# Out:
# 0.7165937354436941

# %%
rfc5.fit(X_train_top10_2, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=25,
#                        min_samples_split=4, n_estimators=300, random_state=42)

# %%
y_train_pred5 = rfc5.predict(X_train_top10_2)
y_train_pred_proba5 = rfc5.predict_proba(X_train_top10_2)

y_test_pred5 = rfc5.predict(X_test_top10_2)
y_test_pred_proba5 = rfc5.predict_proba(X_test_top10_2)

# %%
RocCurveDisplay.from_estimator(rfc5, X_train_top10_2, y_train)
plt.title("Train ROC Curve, top 10 features")
RocCurveDisplay.from_estimator(rfc5, X_test_top10_2, y_test)
plt.title("Test ROC Curve, top 10 features")
# Out:
# Text(0.5, 1.0, 'Test ROC Curve, top 10 features')

# %%
#plot train PR Curve 
train_precision5, train_recall5, train_thresholds5 = precision_recall_curve(y_train, y_train_pred_proba5[:, 1])
train_auc_precision_recall5 = auc(train_recall5, train_precision5)
print('Train PR-AUC is {:.2f}'.format(train_auc_precision_recall5))

print('min threshold:{:.2f}'.format(min(train_thresholds5)), 'max threshold:{:.2f}'.format(max(train_thresholds5)))

plt.plot(train_recall5, train_precision5)
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Train Precision-Recall Curve, top 10 features,PRAUC=1.0')
# Out:
# Train PR-AUC is 1.00
# min threshold:0.57 max threshold:1.00
# Text(0.5, 1.0, 'Train Precision-Recall Curve, top 10 features,PRAUC=1.0')

# %%
test_precision5, test_recall5, test_thresholds5 = precision_recall_curve(y_test, y_test_pred_proba5[:, 1])
test_auc_precision_recall5 = auc(test_recall5, test_precision5)
print('Test PR-AUC is {:.2f}'.format(test_auc_precision_recall5))

print('min threshold:{:.2f}'.format(min(test_thresholds5)), 'max threshold:{:.2f}'.format(max(test_thresholds5)))

plt.plot(test_recall5, test_precision5)
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Test Precision-Recall Curve, top 10 features,PRAUC=0.72')
plt.show()
# Out:
# Test PR-AUC is 0.72
# min threshold:0.00 max threshold:1.00

# %%
# calibrate probability

calibrated_clf5 = CalibratedClassifierCV(base_estimator=rfc5,cv='prefit',method = 'isotonic')
calibrated_clf5.fit(X_test_top10_2, y_test)
# Out:
# CalibratedClassifierCV(base_estimator=RandomForestClassifier(class_weight='balanced',
#                                                              max_depth=25,
#                                                              min_samples_split=4,
#                                                              n_estimators=300,
#                                                              random_state=42),
#                        cv='prefit', method='isotonic')

# %%
y_test_proba_isotonic5 = calibrated_clf5.predict_proba(X_test_top10_2)

# %%
thresholds = np.arange(0,1,0.05,dtype = float)
prec_scores5_isotonic = []
recall_scores5_isotonic = []

for i in range(len(thresholds)):
    y_test_pred_new = (calibrated_clf5.predict_proba(X_test_top10_2)[:,1]>thresholds[i]).astype(int)
    prec_scores5_isotonic.append(precision_score(y_test, y_test_pred_new))
    recall_scores5_isotonic.append(recall_score(y_test, y_test_pred_new))

plt.plot(thresholds, prec_scores5_isotonic, marker = 'o',label = 'precision scores')
plt.plot(thresholds, recall_scores5_isotonic,marker = 'o',label = 'recall scores')
plt.legend()
plt.title('Calibrated Test Precision and Recall Scores, Top 10 Features')
plt.xlabel("Threshold Values")
plt.show()

# %% [markdown]
# ### Check the collinearity of Top 15 features

# %%
top15features = logreg_importances.sort_values(ascending = False)[:15].index

# %%
X_train_top15_2 = X_train[top15features]
X_test_top15_2 = X_test[top15features]

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(8,8)})
dataplot=sns.heatmap(X_train_top15_2.corr(method = 'pearson'), annot=True)
plt.show()

# %%
top15features
# Out:
# Index(['MaxHospitalDays', 'TotalInscClaimAmtReimbursed', 'totalDiagCode_41401',
#        'TotalIPAnnualReimbursementAmt', 'MaxInscClaimAmtReimbursed',
#        'TotalProcCodeNum', 'TotalIPAnnualDeductibleAmtdf',
#        'totalDiagCode_4280', 'TotalMediumHighFreqProcCodeNumPerClaim',
#        'MaxDiagCodeNumPerClaim', 'TotalDiagCodeNum', 'MaxProcCodeNumPerClaim',
#        'MeanProcCodeNumPerClaim', 'TotalMediumFreqProcCodeNumPerClaim',
#        'totalDiagCode_42731'],
#       dtype='object')

# %% [markdown]
# TotalInscClaimAmtReimbursed - - TotalProcCodeNum- TotalMediumFreqProcCodeNumPerClaim' - TotalHighFreqProcCodeNumPerClaim'

# %% [markdown]
# totalDiagCode_41401 -TotalIPAnnualReimbursementAmt' - TotalIPAnnualDeductibleAmtdf' -  'totalDiagCode_4280'- 'totalDiagCode_42731'

# %% [markdown]
#  'TotalIPAnnualReimbursementAmt'- TotalIPAnnualDeductibleAmtdf- 4280 - TotalDiagCodeNum - 42731

# %%
to_be_removed2= ['TotalProcCodeNum','TotalMediumFreqProcCodeNumPerClaim','TotalMediumHighFreqProcCodeNumPerClaim',
                 'TotalIPAnnualDeductibleAmtdf','totalDiagCode_4280','totalDiagCode_41401','totalDiagCode_42731']

# %% [markdown]
# ### Remove 7 highly correlated features and re-train RandomForest

# %%
top8features = []
for item in top15features:
    if item not in to_be_removed2:
        top8features.append(item)
top8features
# Out:
# ['MaxHospitalDays',
#  'TotalInscClaimAmtReimbursed',
#  'TotalIPAnnualReimbursementAmt',
#  'MaxInscClaimAmtReimbursed',
#  'MaxDiagCodeNumPerClaim',
#  'TotalDiagCodeNum',
#  'MaxProcCodeNumPerClaim',
#  'MeanProcCodeNumPerClaim']

# %%
X_train_top8 = X_train[top8features]
X_test_top8 = X_test[top8features]

display(X_train_top8.shape, X_test_top8.shape)
# Out:
# (4328, 8)
# (1082, 8)

# %%
#param_grid = {
#              'max_depth': [15,20,25,30,50],
#            'n_estimators':[150,300,500,700],
#            'min_samples_split':[2,4,6,8]}
#rfc6 = RandomForestClassifier(class_weight = 'balanced', random_state = 42)
#rfc6_gsv = GridSearchCV(rfc6, param_grid = param_grid,scoring = 'average_precision',cv=5)
#rfc6_gsv.fit(X_train_top8, y_train)
#rfc6_gsv.best_params_
# Out:
# {'max_depth': 20, 'min_samples_split': 8, 'n_estimators': 700}

# %%
rfc6 = RandomForestClassifier(max_depth = 20, min_samples_split = 8, n_estimators =700, class_weight = 'balanced', random_state = 42)
train_scores6 = cross_val_score(rfc6, X_train_top8, y_train, scoring= 'average_precision', cv=5)

# %%
train_scores6.mean()
# Out:
# 0.7075516248511153

# %%
rfc6.fit(X_train_top8, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=20,
#                        min_samples_split=8, n_estimators=700, random_state=42)

# %%
y_train_pred6 = rfc6.predict(X_train_top8)
y_train_pred_proba6 = rfc6.predict_proba(X_train_top8)

y_test_pred6 = rfc6.predict(X_test_top8)
y_test_pred_proba6 = rfc6.predict_proba(X_test_top8)

# %%
sns.set(rc={'figure.figsize':(6,4)})
RocCurveDisplay.from_estimator(rfc6, X_train_top8, y_train)
plt.title("Train ROC Curve, Select top 8 features features")
RocCurveDisplay.from_estimator(rfc6, X_test_top8, y_test)
plt.title("Test ROC Curve, Select top 8 features features")
# Out:
# Text(0.5, 1.0, 'Test ROC Curve, Select top 8 features features')

# %%
#plot train PR Curve 
train_precision6, train_recall6, train_thresholds6 = precision_recall_curve(y_train, y_train_pred_proba6[:, 1])
train_auc_precision_recall6 = auc(train_recall6, train_precision6)
print('Train PR-AUC is {:.2f}'.format(train_auc_precision_recall6))

print('min threshold:{:.2f}'.format(min(train_thresholds6)), 'max threshold:{:.2f}'.format(max(train_thresholds6)))

plt.plot(train_recall6, train_precision6)
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Train Precision-Recall Curve, Select top 8 features,PRAUC=0.99')
# Out:
# Train PR-AUC is 0.99
# min threshold:0.50 max threshold:1.00
# Text(0.5, 1.0, 'Train Precision-Recall Curve, Select top 8 features,PRAUC=0.99')

# %%
test_precision6, test_recall6, test_thresholds6 = precision_recall_curve(y_test, y_test_pred_proba6[:, 1])
test_auc_precision_recall6 = auc(test_recall6, test_precision6)
print('Test PR-AUC is {:.2f}'.format(test_auc_precision_recall6))

print('min threshold:{:.2f}'.format(min(test_thresholds6)), 'max threshold:{:.2f}'.format(max(test_thresholds6)))

plt.plot(test_recall6, test_precision6)
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Test Precision-Recall Curve, Select top 10 features,PRAUC=0.73')
plt.show()
# Out:
# Test PR-AUC is 0.73
# min threshold:0.00 max threshold:0.99

# %%
# calibrate probability

calibrated_clf6 = CalibratedClassifierCV(base_estimator=rfc6,cv='prefit',method = 'isotonic')
calibrated_clf6.fit(X_test_top8, y_test)
# Out:
# CalibratedClassifierCV(base_estimator=RandomForestClassifier(class_weight='balanced',
#                                                              max_depth=20,
#                                                              min_samples_split=8,
#                                                              n_estimators=700,
#                                                              random_state=42),
#                        cv='prefit', method='isotonic')

# %%
y_test_proba_isotonic6 = calibrated_clf6.predict_proba(X_test_top8)

# %%
thresholds = np.arange(0,1,0.05,dtype = float)
prec_scores6_isotonic = []
recall_scores6_isotonic = []

for i in range(len(thresholds)):
    y_test_pred_new = (calibrated_clf6.predict_proba(X_test_top8)[:,1]>thresholds[i]).astype(int)
    prec_scores6_isotonic.append(precision_score(y_test, y_test_pred_new))
    recall_scores6_isotonic.append(recall_score(y_test, y_test_pred_new))

plt.plot(thresholds, prec_scores6_isotonic, marker = 'o',label = 'precision scores')
plt.plot(thresholds, recall_scores6_isotonic,marker = 'o',label = 'recall scores')
plt.legend()
plt.title('Calibrated Test Precision and Recall Scores vs.Thresholds, Select Top 8 Features')
plt.xlabel('Threshold Values')
plt.show()

# %%
prec_scores6_isotonic
# Out:
# [0.09519408502772643,
#  0.4266666666666667,
#  0.4266666666666667,
#  0.4945652173913043,
#  0.5477707006369427,
#  0.74,
#  0.74,
#  0.74,
#  0.74,
#  0.74,
#  0.74,
#  0.74,
#  0.74,
#  0.86,
#  0.86,
#  0.8695652173913043,
#  0.9285714285714286,
#  0.9285714285714286,
#  0.9285714285714286,
#  1.0]

# %%
recall_scores6_isotonic
# Out:
# [1.0,
#  0.9320388349514563,
#  0.9320388349514563,
#  0.883495145631068,
#  0.8349514563106796,
#  0.7184466019417476,
#  0.7184466019417476,
#  0.7184466019417476,
#  0.7184466019417476,
#  0.7184466019417476,
#  0.7184466019417476,
#  0.7184466019417476,
#  0.7184466019417476,
#  0.4174757281553398,
#  0.4174757281553398,
#  0.3883495145631068,
#  0.2524271844660194,
#  0.2524271844660194,
#  0.2524271844660194,
#  0.038834951456310676]

# %%
# Summary Train PR Curve
line1, = plt.plot(train_recall2, train_precision2,label= 'balanced, all features, PR-AUC = 1.0')
line2, = plt.plot(train_recall3, train_precision3,label= 'balanced, Top 50 features, PR-AUC = 1.0')
line3, = plt.plot(train_recall4, train_precision4,label= 'balanced, Top 25 features, PR-AUC = 1.0')
line4, = plt.plot(train_recall5, train_precision5,label= 'balanced, Top 10 features, PR-AUC = 1.0')
line5, = plt.plot(train_recall6, train_precision6,label= 'balanced, Select Top 8 features, PR-AUC = 0.99')

plt.legend(handles=[line1, line2,line3, line4, line5])
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Train Precision-Recall Curve')
plt.ylim([0,1.1])
plt.show()

# %%
# Summary Test PR-Curve
line1, = plt.plot(test_recall2, test_precision2,label= 'balanced, all features, PR-AUC = 0.70')
line2, = plt.plot(test_recall3, test_precision3,label= 'balanced, Top 50 features, PR-AUC = 0.71')
line3, = plt.plot(test_recall4, test_precision4,label= 'balanced, Top 25 features, PR-AUC = 0.72')
line4, = plt.plot(test_recall5, test_precision5,label= 'balanced, Top 10 features, PR-AUC = 0.72')
line5, = plt.plot(test_recall6, test_precision6,label= 'balanced, Select Top 8 features, PR-AUC = 0.73')

plt.legend(handles=[line1, line2,line3, line4, line5])
plt.xlabel('Recall(Positive label:1)')
plt.ylabel('Precision(Positive label:1)')
plt.title('Test Precision-Recall Curve')
plt.show()
